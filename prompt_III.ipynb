# %% [markdown]
# # Practical Application III: Comparing Classifiers
#
# **Overview**: In this practical application, your goal is to compare the performance of the classifiers we encountered in this section, namely K Nearest Neighbor, Logistic Regression, Decision Trees, and Support Vector Machines.  We will utilize a dataset related to marketing bank products over the telephone.

# %% [markdown]
# ### Getting Started
#
# Our dataset comes from the UCI Machine Learning repository [link](https://archive.ics.uci.edu/ml/datasets/bank+marketing).  The data is from a Portugese banking institution and is a collection of the results of multiple marketing campaigns.  We will make use of the article accompanying the dataset [here](CRISP-DM-BANK.pdf) for more information on the data and features.

# %% [markdown]
# ### Problem 1: Understanding the Data
#
# To gain a better understanding of the data, please read the information provided in the UCI link above, and examine the **Materials and Methods** section of the paper.  How many marketing campaigns does this data represent?

# %% [markdown]
# **Answer**:
#
# This data represents 17 direct marketing campaigns that were conducted from 2008 to 2010.

# %% [markdown]
# ### Problem 2: Read in the Data
#
# Use pandas to read in the dataset `bank-additional-full.csv` and assign to a meaningful variable name.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import time

import warnings
warnings.filterwarnings(action='ignore', category=FutureWarning)

# %%
df = pd.read_csv('data/bank-additional-full.csv', sep = ';')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %% [markdown]
# **Observation**
#
# While the `info()` method of the data frame indicates that there are no `null` values in the dataset, a closer look shows that there are values like `unknown` in the dataset, like seen in the second row of the column `default` that suggests there are `null` values missing from the dataset in certain columns. The field descriptions below provide other such values, such as `999` and `nonexistent`.

# %% [markdown]
# ### Problem 3: Understanding the Features
#
#
# Examine the data description below, and determine if any of the features are missing values or need to be coerced to a different data type.
#
#
# ```
# Input variables:
# # bank client data:
# 1 - age (numeric)
# 2 - job : type of job (categorical: 'admin.','blue-collar','entrepreneur','housemaid','management','retired','self-employed','services','student','technician','unemployed','unknown')
# 3 - marital : marital status (categorical: 'divorced','married','single','unknown'; note: 'divorced' means divorced or widowed)
# 4 - education (categorical: 'basic.4y','basic.6y','basic.9y','high.school','illiterate','professional.course','university.degree','unknown')
# 5 - default: has credit in default? (categorical: 'no','yes','unknown')
# 6 - housing: has housing loan? (categorical: 'no','yes','unknown')
# 7 - loan: has personal loan? (categorical: 'no','yes','unknown')
# # related with the last contact of the current campaign:
# 8 - contact: contact communication type (categorical: 'cellular','telephone')
# 9 - month: last contact month of year (categorical: 'jan', 'feb', 'mar', ..., 'nov', 'dec')
# 10 - day_of_week: last contact day of the week (categorical: 'mon','tue','wed','thu','fri')
# 11 - duration: last contact duration, in seconds (numeric). Important note: this attribute highly affects the output target (e.g., if duration=0 then y='no'). Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known. Thus, this input should only be included for benchmark purposes and should be discarded if the intention is to have a realistic predictive model.
# # other attributes:
# 12 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
# 13 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
# 14 - previous: number of contacts performed before this campaign and for this client (numeric)
# 15 - poutcome: outcome of the previous marketing campaign (categorical: 'failure','nonexistent','success')
# # social and economic context attributes
# 16 - emp.var.rate: employment variation rate - quarterly indicator (numeric)
# 17 - cons.price.idx: consumer price index - monthly indicator (numeric)
# 18 - cons.conf.idx: consumer confidence index - monthly indicator (numeric)
# 19 - euribor3m: euribor 3 month rate - daily indicator (numeric)
# 20 - nr.employed: number of employees - quarterly indicator (numeric)
#
# Output variable (desired target):
# 21 - y - has the client subscribed a term deposit? (binary: 'yes','no')
# ```

# %%
# columns with missing values
df.replace({'unknown': None, 'nonexistent': None, 999: None}).isna().sum().sort_values(ascending=False).to_frame(name='count').query('count > 0')
# Out:
#            count
# pdays      39673
# poutcome   35563
# default     8597
# education   1731
# loan         990
# housing      990
# job          330
# marital       80
# duration       2

# %% [markdown]
# **Columns to drop**
# - poutcome, default: too many missing values
# - duration: duration is not known before a call is performed

# %%
X = df.drop(columns=['poutcome', 'default', 'duration', 'pdays']).replace({'unknown': None, 'nonexistent': None, 999: None}).dropna()
X.info()
print(f'{X.shape[0]/df.shape[0]:.1%}')
X.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38245 entries, 0 to 41187
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             38245 non-null  int64
#  1   job             38245 non-null  object
#  2   marital         38245 non-null  object
#  3   education       38245 non-null  object
#  4   housing         38245 non-null  object
#  5   loan            38245 non-null  object
#  6   contact         38245 non-null  object
#  7   month           38245 non-null  object
#  8   day_of_week     38245 non-null  object
#  9   campaign        38245 non-null  int64
#  10  previous        38245 non-null  int64
#  11  emp.var.rate    38245 non-null  float64
#  12  cons.price.idx  38245 non-null  float64
#  13  cons.conf.idx   38245 non-null  float64
#  14  euribor3m       38245 non-null  float64
#  15  nr.employed     38245 non-null  float64
#  16  y               38245 non-null  object
# ...

# %%
X.describe(include=object)
# Out:
#            job  marital          education housing   loan   contact  month  \
# count    38245    38245              38245   38245  38245     38245  38245
# unique      11        3                  7       2      2         2     10
# top     admin.  married  university.degree     yes     no  cellular    may
# freq      9937    23183              11821   20578  32286     24441  12794
#
#        day_of_week      y
# count        38245  38245
# unique           5      2
# top            thu     no
# freq          8011  33987

# %%
X.describe()
# Out:
#                 age      campaign      previous  emp.var.rate  cons.price.idx  \
# count  38245.000000  38245.000000  38245.000000  38245.000000    38245.000000
# mean      39.860871      2.566662      0.170009      0.082861       93.570313
# std       10.289488      2.767473      0.487169      1.565945        0.576367
# min       17.000000      1.000000      0.000000     -3.400000       92.201000
# 25%       32.000000      1.000000      0.000000     -1.800000       93.075000
# 50%       38.000000      2.000000      0.000000      1.100000       93.444000
# 75%       47.000000      3.000000      0.000000      1.400000       93.994000
# max       98.000000     43.000000      7.000000      1.400000       94.767000
#
#        cons.conf.idx     euribor3m   nr.employed
# count   38245.000000  38245.000000  38245.000000
# mean      -40.541164      3.623298   5167.432566
# std         4.623200      1.730226     71.760333
# min       -50.800000      0.634000   4963.600000
# ...

# %%
# convert y column to binary 1, 0 so that we can detect correlations
X.y = np.where(X.y == 'yes', 1, 0)
X.info()
X.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38245 entries, 0 to 41187
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             38245 non-null  int64
#  1   job             38245 non-null  object
#  2   marital         38245 non-null  object
#  3   education       38245 non-null  object
#  4   housing         38245 non-null  object
#  5   loan            38245 non-null  object
#  6   contact         38245 non-null  object
#  7   month           38245 non-null  object
#  8   day_of_week     38245 non-null  object
#  9   campaign        38245 non-null  int64
#  10  previous        38245 non-null  int64
#  11  emp.var.rate    38245 non-null  float64
#  12  cons.price.idx  38245 non-null  float64
#  13  cons.conf.idx   38245 non-null  float64
#  14  euribor3m       38245 non-null  float64
#  15  nr.employed     38245 non-null  float64
#  16  y               38245 non-null  int64
# ...

# %% [markdown]
# ### Problem 4: Understanding the Task
#
# After examining the description and data, your goal now is to clearly state the *Business Objective* of the task.  State the objective below.

# %% [markdown]
# **Data Exploration**

# %%
corr = X.corr(numeric_only=True).round(3)
plt.figure(figsize= (15,8))
sns.heatmap(corr, annot= True)
plt.title('Correlation Matrix of Numerical Features with Target Classes');

# %%
# descriptive statistics of distribution of numerical features
X.describe()
# Out:
#                 age      campaign      previous  emp.var.rate  cons.price.idx  \
# count  38245.000000  38245.000000  38245.000000  38245.000000    38245.000000
# mean      39.860871      2.566662      0.170009      0.082861       93.570313
# std       10.289488      2.767473      0.487169      1.565945        0.576367
# min       17.000000      1.000000      0.000000     -3.400000       92.201000
# 25%       32.000000      1.000000      0.000000     -1.800000       93.075000
# 50%       38.000000      2.000000      0.000000      1.100000       93.444000
# 75%       47.000000      3.000000      0.000000      1.400000       93.994000
# max       98.000000     43.000000      7.000000      1.400000       94.767000
#
#        cons.conf.idx     euribor3m   nr.employed             y
# count   38245.000000  38245.000000  38245.000000  38245.000000
# mean      -40.541164      3.623298   5167.432566      0.111335
# std         4.623200      1.730226     71.760333      0.314550
# ...

# %%
# distribution of target classes: heavily skewed
X.y.plot(kind='hist')
plt.title('Target Class Distribution')
# Out:
# Text(0.5, 1.0, 'Target Class Distribution')

# %%
# distribution of categorical features
fig, ax = plt.subplots(1, 4, figsize=(14, 4))
sns.histplot(X, y='job', ax=ax[0])
sns.histplot(X, y='marital', ax=ax[1])
sns.histplot(X, y='education', ax=ax[2])
sns.histplot(X, y='housing', ax=ax[3])
plt.suptitle('Distribution of Job, Marital, Education and Housing Categorical Features')
plt.tight_layout()

# %%
# distribution of categorical features
fig, ax = plt.subplots(1, 4, figsize=(14, 4))
sns.histplot(X, y='loan', ax=ax[0])
sns.histplot(X, y='contact', ax=ax[1])
sns.histplot(X, y='month', ax=ax[2])
sns.histplot(X, y='day_of_week', ax=ax[3])
plt.suptitle('Distribution of Loan, Contact, Month and Day of Week Categorical Features')
plt.tight_layout()

# %% [markdown]
# **Business Objective Statement**

# %% [markdown]
# Based on the data collected, determine the factors that best predict successful subscriptions so that the bank improve the efficiency of its marketing campaigns, e.g. when to run them, what kinds of customers to target, whether to reach on cell phones, etc.

# %% [markdown]
# ### Problem 5: Engineering Features
#
# Now that you understand your business objective, we will build a basic model to get started.  Before we can do this, we must work to encode the data.  Using just the bank information features, prepare the features and target column for modeling with appropriate encoding and transformations.

# %% [markdown]
# **Explanation**
#
# I first attempted to preserve as many records as possible. I tried to only drop the rows where `default` was `unknown` and impute the rest. I ended up getting a lot of jupyter kernel errors. After struggling for a long time without success, I decided to simply drop all rows with values that include 'unknown'.
#
#
# **Implication:** In both cases, no imputation is required. There will be no null valued cell to impute. Either they are populated with a category that has a value of 'unknown', or those rows will be dropped.
#
# **Other Observations** Pair plot did not suggest polynomial relationship. No feature engineering initially suggested from exploratory data analysis.
#
# **Feature Engineering Strategy**
# - One-Hot encoding of categorical features
# - Standard scaling of numerical features

# %%
categorical_cols = X.select_dtypes(object).columns.to_list()
categorical_cols
# Out:
# ['job',
#  'marital',
#  'education',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week']

# %%
from sklearn.compose import make_column_selector, make_column_transformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder, PolynomialFeatures
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, recall_score, precision_score
from sklearn.dummy import DummyClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

transformer = make_column_transformer(
  (OneHotEncoder(), categorical_cols),     # OHE of categorical data
  remainder=StandardScaler()
)
transformer
# Out:
# ColumnTransformer(remainder=StandardScaler(),
#                   transformers=[('onehotencoder', OneHotEncoder(),
#                                  ['job', 'marital', 'education', 'housing',
#                                   'loan', 'contact', 'month', 'day_of_week'])])

# %% [markdown]
# ### Problem 6: Train/Test Split
#
# With your data prepared, split it into a train and test set.

# %%
from sklearn.model_selection import train_test_split

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X.drop(columns=['y']), X.y, test_size=0.3, random_state=42, stratify=X.y)

# %% [markdown]
# ### Problem 7: A Baseline Model
#
# Before we build our first model, we want to establish a baseline.  What is the baseline performance that our classifier should aim to beat?

# %%
baseline = (X.shape[0]-X.y.sum())/X.shape[0]
print(f'{baseline:.1%}')
# Out:
# 88.9%

# %% [markdown]
# **Expectation**
#
# We should expect our classifiers to perform better than 88.9% accuracy.

# %% [markdown]
# ### Problem 8: A Simple Model
#
# Use Logistic Regression to build a basic model on your data.

# %%
lr_pipe = Pipeline([('prep', transformer),('classify', LogisticRegression())])
lr_pipe.fit(X_train, y_train)
lr_pipe
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(remainder=StandardScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   ['job', 'marital',
#                                                    'education', 'housing',
#                                                    'loan', 'contact', 'month',
#                                                    'day_of_week'])])),
#                 ('classify', LogisticRegression())])

# %% [markdown]
# ### Problem 9: Score the Model
#
# What is the accuracy of your model?

# %%
print(f'Accuracy on train data: {lr_pipe.score(X_train, y_train):.1%}')
print(f'Accuracy on test data: {lr_pipe.score(X_test, y_test):.1%}')
# Out:
# Accuracy on train data: 89.4%
# Accuracy on test data: 89.3%

# %% [markdown]
# **Result**
#
# This is an improvement over the baseline model.

# %% [markdown]
# ### Problem 10: Model Comparisons
#
# Now, we aim to compare the performance of the Logistic Regression model to our KNN algorithm, Decision Tree, and SVM models.  Using the default settings for each of the models, fit and score each.  Also, be sure to compare the fit time of each of the models.  Present your findings in a `DataFrame` similar to that below:
#
# | Model | Train Time | Train Accuracy | Test Accuracy |
# | ----- | ---------- | -------------  | -----------   |
# |     |    |.     |.     |

# %%
# define the models to evaluate
models = [
  DummyClassifier(),
  LogisticRegression(),
  KNeighborsClassifier(),
  DecisionTreeClassifier(),
  SVC(),
]

# %%
# helper method to create and fit a pipeline using the specified classifier 
def evaluate_estimator(classifier):
  # define the training pipeline
  pipe = Pipeline([('prep', transformer), ('classify', classifier)])
  # measure the training time
  tstart = time.perf_counter()
  pipe.fit(X_train, y_train)
  train_time = time.perf_counter() - tstart
  # compute the accuracy of the model
  train_acc = accuracy_score(y_train, pipe.predict(X_train))
  test_acc = accuracy_score(y_test, pipe.predict(X_test))
  return (type(classifier).__name__, train_time, train_acc, test_acc)

# %%
# evaluate the models
results = pd.DataFrame(
  [evaluate_estimator(model) for model in models],
  columns=['Model', 'Train Time (s)', 'Train Accuracy', 'Test Accuracy']
)
results
# Out:
#                     Model  Train Time (s)  Train Accuracy  Test Accuracy
# 0         DummyClassifier        0.059294        0.888648       0.888705
# 1      LogisticRegression        0.165287        0.894139       0.893498
# 2    KNeighborsClassifier        0.058983        0.909604       0.887659
# 3  DecisionTreeClassifier        0.269086        0.995032       0.837807
# 4                     SVC       43.782692        0.902357       0.896462

# %% [markdown]
# ### Problem 11: Improving the Model
#
# Now that we have some basic models on the board, we want to try to improve these.  Below, we list a few things to explore in this pursuit.
#
# - More feature engineering and exploration.  For example, should we keep the gender feature?  Why or why not?
# - Hyperparameter tuning and grid search.  All of our models have additional hyperparameters to tune and explore.  For example the number of neighbors in KNN or the maximum depth of a Decision Tree.
# - Adjust your performance metric

# %% [markdown]
# **Features to Drop**

# %%
# extract the derived feature names from the transformer
feature_names = [name.split('__')[-1] for name in lr_pipe.named_steps['prep'].get_feature_names_out()]
feature_names[:5]
# Out:
# ['job_admin.',
#  'job_blue-collar',
#  'job_entrepreneur',
#  'job_housemaid',
#  'job_management']

# %%
# extract the coefficients from the logistic regression fit
coefficients = lr_pipe.named_steps["classify"].coef_[0]

# plot the coefficient in order of log-odds, prob of event increasing with unit change in value of predictor variable 
fig, ax = plt.subplots(figsize=(10,15))
lr_results = pd.DataFrame({'columns': feature_names,'values': coefficients}).sort_values('values')
lr_results.plot(kind='barh', x='columns', y='values', legend=False, ax=ax)
plt.title('Logistic Regression Coefficients')
plt.grid()
plt.show()

# %% [markdown]
# **Observations**
#
# While gender is not in dataset, it does appear that some variables or values do not seem to change the probability of the event. Specifically, the following see to not carry much informational value:
#   - age
#   - day of week
#   - marital status
#   - loan

# %% [markdown]
# **Hyperparameter Tuning**

# %%
# Define grid search parameters
params = [
  # dummy classifier
  {'classify__strategy': ['most_frequent', 'prior', 'stratified', 'uniform']},
  # logistic regression classifier
  {'classify__C': [.001, .01, .1, 1]},
  # nearest neighbor classifier
  {'classify__n_neighbors': [1, 2, 5, 7, 10, 20, 50]},
  # decision tree classifier
  {'classify__max_depth': [1, 2, 5, 10, None]},
  # support vector machine classifier
  {'classify__C': [.001, .01, .1, 1, 2]},
]

# %%
# evaluate hyperparameters
def evaluate_hyperparams(estimator, params):
  grid = GridSearchCV(Pipeline([('prep', transformer),('classify', estimator)]), param_grid=params)
  grid.fit(X_train, y_train)
  return (
    type(estimator).__name__, 
    grid.cv_results_['mean_fit_time'][grid.best_index_],
    grid.score(X_train, y_train),
    grid.score(X_test, y_test)
  )

# %%
results = pd.DataFrame(
  [evaluate_hyperparams(estimator, params) for estimator, params in zip(models, params)],
  columns=['Model', 'Train Time (s)', 'Train Accuracy', 'Test Accuracy']
)
results
# Out:
#                     Model  Train Time (s)  Train Accuracy  Test Accuracy
# 0         DummyClassifier        0.056005        0.888648       0.888705
# 1      LogisticRegression        0.101291        0.894513       0.895329
# 2    KNeighborsClassifier        0.051006        0.898696       0.893063
# 3  DecisionTreeClassifier        0.100728        0.898398       0.896113
# 4                     SVC       24.613693        0.902357       0.896462

# %% [markdown]
# ##### Questions
